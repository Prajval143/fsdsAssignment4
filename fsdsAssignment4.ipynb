# %% [markdown]
# 1.list

# %% [markdown]
# 2.spam=[2,4,6,8,10]
# spam[2]='hello'
# spam
# [2, 4, 'hello', 8, 10]

# %% [markdown]
# 3.spam[int(int('3'* 2) / 11)]===>'d'

# %% [markdown]
# 4.spam[-1]=====>'d'

# %% [markdown]
# 5.spam[:2]=====>['a', 'b']

# %% [markdown]
# 6.bacon.index('cat')====>1

# %% [markdown]
# 7.bacon.append(99)=====>[3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# 8.[3.14, 11, 'cat', True, 99]

# %% [markdown]
# 9.The operator for list concatenation is +, while the operator for replication is *

# %% [markdown]
# 10.The only difference between append() and insert() is that insert function allows us to add a specific element at a specified index of the list unlike append() where we can add the element only at end of the lis

# %% [markdown]
# 11.remove(), pop()

# %% [markdown]
# 12.The similarity between Lists and Strings in Python is that both are sequences

# %% [markdown]
# 13.The key difference between the tuples and lists is that while the tuples are immutable objects the lists are mutable

# %% [markdown]
# 14.(42)

# %% [markdown]
# 15.by type casting list to tuple and tuple to list

# %% [markdown]
# 16.Variables will contain references to list values rather than list values themselves. But for strings and integer values, variables simply contain the string or integer value.

# %% [markdown]
# 17.copy() create reference to original object. If you change copied object - you change the original object. . deepcopy() creates new object and does real copying of original object to new one. Changing new deepcopied object doesn't affect original object.
